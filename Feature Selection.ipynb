# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data/df_fe.csv', sep=",")
df['Date'] = pd.to_datetime(df['Date'])

#df.drop(index=1, inplace=True)
df.head(3)
# Out:
#         Date          Open          High           Low         Close  \
# 0 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 1 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
#
#       Adj Close    Volume($) Symbol  Daily Return        SMA_30  ...  \
# 0  29374.152344  40730301359    BTC      0.012842  22428.243750  ...
# 1  32127.267578  67865420765    BTC      0.093726  22850.972721  ...
# 2  32782.023438  78665235202    BTC      0.020380  23320.381315  ...
#
#     Close_lag_7  Volume_lag_7  Close_rolling_mean_7  Close_rolling_std_7  \
# 0  24664.791016  4.206840e+10          27767.629185          1284.059118
# 1  26437.037109  4.833265e+10          28580.519252          1936.633106
# 2  26272.294922  6.647990e+10          29510.480469          2189.909798
#
#    Volume_rolling_mean_7  Volume_rolling_std_7  Close_rolling_mean_30  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16044 entries, 0 to 16043
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    16044 non-null  datetime64[ns]
#  1   Open                    16044 non-null  float64
#  2   High                    16044 non-null  float64
#  3   Low                     16044 non-null  float64
#  4   Close                   16044 non-null  float64
#  5   Adj Close               16044 non-null  float64
#  6   Volume($)               16044 non-null  int64
#  7   Symbol                  16044 non-null  object
#  8   Daily Return            16044 non-null  float64
#  9   SMA_30                  16044 non-null  float64
#  10  SMA_60                  16044 non-null  float64
#  11  SMA_90                  16044 non-null  float64
#  12  EMA_30                  16044 non-null  float64
#  13  EMA_60                  16044 non-null  float64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numerical columns for correlation analysis
df_numerical = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
corr = df_numerical.corr()

# Create a larger heatmap
plt.figure(figsize=(20, 17))
sns.heatmap(corr, cmap="Blues", annot=True, fmt=".2f")

# Improve layout to handle overlap, rotation of labels for readability
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=45)
plt.title("Correlation Matrix of Cryptocurrency Features")

# Show plot
plt.show()

# %%
df.to_csv('data/df_fe.csv', index=False)
